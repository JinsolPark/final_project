# %%
#-- EDA tool--#
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family=font_name)
import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 실거래가 데이터

# %%
df = pd.read_csv("../data/transaction/transaction_appended.csv")
df
# Out:
#         Unnamed: 0     본번    부번                  addr             load_addr  \
# 0                0  658.0   1.0   서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 1                1  658.0   1.0   서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 2                2  658.0   1.0   서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 3                3  652.0   0.0     서울특별시 강남구 개포동 652     서울특별시 강남구 개포로 307
# 4                4   12.0   2.0    서울특별시 강남구 개포동 12-2  서울특별시 강남구 개포로109길 69
# ...            ...    ...   ...                   ...                   ...
# 280998       27505  450.0   0.0     서울특별시 중랑구 중화동 450     서울특별시 중랑구 동일로 752
# 280999       27506  450.0   0.0     서울특별시 중랑구 중화동 450     서울특별시 중랑구 동일로 752
# 281000       27507  450.0   0.0     서울특별시 중랑구 중화동 450     서울특별시 중랑구 동일로 752
# 281001       27508  274.0  51.0  서울특별시 중랑구 중화동 274-51  서울특별시 중랑구 동일로144길 74
# 281002       27509  274.0  75.0  서울특별시 중랑구 중화동 274-75  서울특별시 중랑구 동일로144길 74
#
#                  dong   bunji  floor           brand  build_area       price  \
# 0       서울특별시 강남구 개포동   658-1      4  개포6차우성아파트1동~8동       79.97  1300000000
# 1       서울특별시 강남구 개포동   658-1      2  개포6차우성아파트1동~8동       79.97  1170000000
# 2       서울특별시 강남구 개포동   658-1      1  개포6차우성아파트1동~8동       79.97  1300000000
# 3       서울특별시 강남구 개포동     652     12          개포우성3차      161.00  2100000000
# 4       서울특별시 강남구 개포동    12-2     16      개포자이(12-2)      170.32  1620000000
# ...               ...     ...    ...             ...         ...         ...
# 280998  서울특별시 중랑구 중화동     450     14             한신2       59.76   660000000
# 280999  서울특별시 중랑구 중화동     450      6             한신2       59.76   660000000
# 281000  서울특별시 중랑구 중화동     450     13             한신2       59.76   680000000
# 281001  서울특별시 중랑구 중화동  274-51      5         한영(101)       57.66   300000000
# 281002  서울특별시 중랑구 중화동  274-75      4         한영(102)       72.22   490000000
#
#         contract_year  contract_month  contract_day  year_built  years_use  \
# 0                2018               1             3        1987         35
# 1                2018               1             8        1987         35
# 2                2018               1            11        1987         35
# 3                2018               1            10        1984         38
# 4                2018               1             2        2004         18
# ...               ...             ...           ...         ...        ...
# 280998           2021               3            18        1998         24
# 280999           2021               4            10        1998         24
# 281000           2021               4            16        1998         24
# 281001           2021               2            27        2003         19
# 281002           2021               5             4        2003         19
#
#          load_name
# 0            언주로 3
# 1            언주로 3
# 2            언주로 3
# 3          개포로 307
# 4       개포로109길 69
# ...            ...
# 280998     동일로 752
# 280999     동일로 752
# 281000     동일로 752
# 281001  동일로144길 74
# 281002  동일로144길 74
#
# [281003 rows x 17 columns]

# %%
df = df.loc[:, "addr":]
df.tail()
# Out:
#                         addr             load_addr           dong   bunji  \
# 280998     서울특별시 중랑구 중화동 450     서울특별시 중랑구 동일로 752  서울특별시 중랑구 중화동     450
# 280999     서울특별시 중랑구 중화동 450     서울특별시 중랑구 동일로 752  서울특별시 중랑구 중화동     450
# 281000     서울특별시 중랑구 중화동 450     서울특별시 중랑구 동일로 752  서울특별시 중랑구 중화동     450
# 281001  서울특별시 중랑구 중화동 274-51  서울특별시 중랑구 동일로144길 74  서울특별시 중랑구 중화동  274-51
# 281002  서울특별시 중랑구 중화동 274-75  서울특별시 중랑구 동일로144길 74  서울특별시 중랑구 중화동  274-75
#
#         floor    brand  build_area      price  contract_year  contract_month  \
# 280998     14      한신2       59.76  660000000           2021               3
# 280999      6      한신2       59.76  660000000           2021               4
# 281000     13      한신2       59.76  680000000           2021               4
# 281001      5  한영(101)       57.66  300000000           2021               2
# 281002      4  한영(102)       72.22  490000000           2021               5
#
#         contract_day  year_built  years_use   load_name
# 280998            18        1998         24     동일로 752
# 280999            10        1998         24     동일로 752
# 281000            16        1998         24     동일로 752
# 281001            27        2003         19  동일로144길 74
# 281002             4        2003         19  동일로144길 74

# %%
df.to_excel("data/transaction/transaction_확인용.xlsx", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281003 entries, 0 to 281002
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   addr            280853 non-null  object
#  1   load_addr       281003 non-null  object
#  2   dong            281003 non-null  object
#  3   bunji           280853 non-null  object
#  4   floor           281003 non-null  int64
#  5   brand           281003 non-null  object
#  6   build_area      281003 non-null  float64
#  7   price           281003 non-null  int64
#  8   contract_year   281003 non-null  int64
#  9   contract_month  281003 non-null  int64
#  10  contract_day    281003 non-null  int64
#  11  year_built      281003 non-null  int64
#  12  years_use       281003 non-null  int64
#  13  load_name       281003 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 30.0+ MB

# %%
x = df[["load_addr","brand"]]
n1 = x.groupby("load_addr").count()
n2 = x.groupby("brand").count()

# %%
n1
# Out:
#                        brand
# load_addr
# 서울특별시 강남구 강남대로 240        33
# 서울특별시 강남구 강남대로 256        32
# 서울특별시 강남구 강남대로 272         6
# 서울특별시 강남구 강남대로 324         9
# 서울특별시 강남구 강남대로112길 41     17
# ...                      ...
# 서울특별시 중랑구 중랑천로12길 17       1
# 서울특별시 중랑구 중랑천로14길 34      25
# 서울특별시 중랑구 중랑천로14길 58      30
# 서울특별시 중랑구 중랑천로2길 48        1
# 서울특별시 중랑구 중랑천로30길 50       4
#
# [8282 rows x 1 columns]

# %%
n2
# Out:
#               load_addr
# brand
# (1-102)               4
# (1101-1)             48
# (13-21)               4
# (1546-0)              2
# (1617-21)             1
# ...                 ...
# 힐튼빌리지1차               1
# 힐튼빌리지2차               3
# 힐하우스                  2
# 힐하우스(577-79)          1
# 힐하우스(802-3)           1
#
# [6997 rows x 1 columns]

# %%
plt.hist(df["floor"])
# Out:
# (array([7.40400e+04, 1.19582e+05, 6.63790e+04, 1.67300e+04, 2.95300e+03,
#         9.14000e+02, 2.55000e+02, 8.50000e+01, 4.10000e+01, 2.40000e+01]),
#  array([-3. ,  4.2, 11.4, 18.6, 25.8, 33. , 40.2, 47.4, 54.6, 61.8, 69. ]),
#  <BarContainer object of 10 artists>)

# %%
df["floor_cat"] = pd.cut(df["floor"], bins=[-3,3,7,12,20,70],labels=["지하~3층","4~7층","8~12층","13~20층","20층 이상"])
df.head()
# Out:
#    Unnamed: 0     본번   부번                 addr             load_addr  \
# 0           0  658.0  1.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 1           1  658.0  1.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 2           2  658.0  1.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 3           3  652.0  0.0    서울특별시 강남구 개포동 652     서울특별시 강남구 개포로 307
# 4           4   12.0  2.0   서울특별시 강남구 개포동 12-2  서울특별시 강남구 개포로109길 69
#
#             dong  bunji  floor           brand  build_area       price  \
# 0  서울특별시 강남구 개포동  658-1      4  개포6차우성아파트1동~8동       79.97  1300000000
# 1  서울특별시 강남구 개포동  658-1      2  개포6차우성아파트1동~8동       79.97  1170000000
# 2  서울특별시 강남구 개포동  658-1      1  개포6차우성아파트1동~8동       79.97  1300000000
# 3  서울특별시 강남구 개포동    652     12          개포우성3차      161.00  2100000000
# 4  서울특별시 강남구 개포동   12-2     16      개포자이(12-2)      170.32  1620000000
#
#    contract_year  contract_month  contract_day  year_built  years_use  \
# 0           2018               1             3        1987         35
# 1           2018               1             8        1987         35
# 2           2018               1            11        1987         35
# 3           2018               1            10        1984         38
# 4           2018               1             2        2004         18
#
#     load_name floor_cat
# 0       언주로 3      4~7층
# 1       언주로 3     지하~3층
# 2       언주로 3     지하~3층
# 3     개포로 307     8~12층
# 4  개포로109길 69    13~20층

# %%
df.head()
# Out:
#    Unnamed: 0     본번   부번                 addr             load_addr  \
# 0           0  658.0  1.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 1           1  658.0  1.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 2           2  658.0  1.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 3           3  652.0  0.0    서울특별시 강남구 개포동 652     서울특별시 강남구 개포로 307
# 4           4   12.0  2.0   서울특별시 강남구 개포동 12-2  서울특별시 강남구 개포로109길 69
#
#             dong  bunji  floor           brand  build_area       price  \
# 0  서울특별시 강남구 개포동  658-1      4  개포6차우성아파트1동~8동       79.97  1300000000
# 1  서울특별시 강남구 개포동  658-1      2  개포6차우성아파트1동~8동       79.97  1170000000
# 2  서울특별시 강남구 개포동  658-1      1  개포6차우성아파트1동~8동       79.97  1300000000
# 3  서울특별시 강남구 개포동    652     12          개포우성3차      161.00  2100000000
# 4  서울특별시 강남구 개포동   12-2     16      개포자이(12-2)      170.32  1620000000
#
#    contract_year  contract_month  contract_day  year_built  years_use  \
# 0           2018               1             3        1987         35
# 1           2018               1             8        1987         35
# 2           2018               1            11        1987         35
# 3           2018               1            10        1984         38
# 4           2018               1             2        2004         18
#
#     load_name floor_cat
# 0       언주로 3      4~7층
# 1       언주로 3     지하~3층
# 2       언주로 3     지하~3층
# 3     개포로 307     8~12층
# 4  개포로109길 69    13~20층

# %%
df.groupby(["load_addr","build_area","floor_cat"])["price"].mean()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-7208c980354d> in <module>
# ----> 1 df.groupby(["load_addr","build_area","floor_cat"])["price"].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1081             raise DataError("No numeric types to aggregate")
#    1082
# -> 1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#    1084
#    1085     @final
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _wrap_aggregated_output(self, output, index)
#     387         """
#     388         result = self._wrap_series_output(output=output, index=index)
# --> 389         return self._reindex_output(result)
#     390
#     391     def _wrap_transformed_output(
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _reindex_output(self, output, fill_value)
#    2884
#    2885         levels_list = [ping.group_index for ping in groupings]
# -> 2886         index, _ = MultiIndex.from_product(
#    2887             levels_list, names=self.grouper.names
#    2888         ).sortlevel()
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in sortlevel(self, level, ascending, sort_remaining)
#    2420                 sortorder = level[0]
#    2421
# -> 2422             indexer = indexer_from_factorized(primary, primshp, compress=False)
#    2423
#    2424             if not ascending:
#
# ~\anaconda3\lib\site-packages\pandas\core\sorting.py in indexer_from_factorized(labels, shape, compress)
#     251
#     252 def indexer_from_factorized(labels, shape, compress: bool = True):
# --> 253     ids = get_group_index(labels, shape, sort=True, xnull=False)
#     254
#     255     if not compress:
#
# ~\anaconda3\lib\site-packages\pandas\core\sorting.py in get_group_index(labels, shape, sort, xnull)
#     159             else:
#     160                 stride //= shape[i]
# --> 161             out += labels[i] * stride
#     162
#     163         if xnull:  # exclude nulls
#
# MemoryError: Unable to allocate 3.48 GiB for an array with shape (467436080,) and data type int64
