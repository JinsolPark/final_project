# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/auction/부동산경매데이터_전체.csv')
data.head(20)
# Out:
#      office          num  cat  \
# 0    서울동부1계   2020-52099  아파트
# 1    서울동부1계   2020-55340  아파트
# 2    서울동부1계   2020-56640  아파트
# 3   서울중앙10계    2020-3254  아파트
# 4   서울중앙10계    2020-3339  아파트
# 5    서울동부4계   2020-55715  아파트
# 6    서울서부6계   2019-52798  아파트
# 7    서울서부3계   2019-54121  아파트
# 8   서울중앙21계  2020-107934  아파트
# 9    서울북부2계  2020-104552  아파트
# 10   서울서부1계    2020-2232  아파트
# 11   서울남부5계    2020-6358  아파트
# 12   서울남부5계    2020-5478  아파트
# 13   서울남부5계    2020-6334  아파트
# 14   서울남부9계  2020-113218  아파트
# 15   서울서부7계   2019-55278  아파트
# 16   서울남부1계  2020-111298  아파트
# 17  서울남부11계  2018-107678  아파트
# 18  서울남부11계  2020-112383  아파트
# 19   서울남부3계    2020-6600  아파트
#
#                                                  addr         build_area  \
# 0           서울특별시 송파구 잠실동 22, 265동 22층2201호 (잠실동,리센츠)   124.22㎡ (37.58평)
# 1     서울특별시 성동구 성수동1가 718, 103동 29층2902호 (성수동1가,트리마제)  84.5402㎡ (25.57평)
# 2                        서울특별시 광진구 구의동 587-58, 3층303호   165.14㎡ (49.95평)
# ...

# %%
data.shape
print(data.info())
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2613 entries, 0 to 2612
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   office      2613 non-null   object
#  1   num         2613 non-null   object
#  2   cat         2613 non-null   object
#  3   addr        2613 non-null   object
#  4   build_area  2588 non-null   object
#  5   land_area   2511 non-null   object
#  6   price       2613 non-null   object
#  7   lowest      2613 non-null   object
#  8   result      814 non-null    object
#  9   date        2613 non-null   object
#  10  status      2613 non-null   object
#  11  low_per     2613 non-null   object
#  12  res_per     814 non-null    object
#  13  comment     268 non-null    object
# dtypes: object(14)
# memory usage: 285.9+ KB
# None
# office           0
# num              0
# cat              0
# addr             0
# build_area      25
# land_area      102
# price            0
# ...

# %%
data['addr']
# Out:
# 0               서울특별시 송파구 잠실동 22, 265동 22층2201호 (잠실동,리센츠)
# 1         서울특별시 성동구 성수동1가 718, 103동 29층2902호 (성수동1가,트리마제)
# 2                            서울특별시 광진구 구의동 587-58, 3층303호
# 3             서울특별시 동작구 상도동 418, 101동 9층906호 (상도동,쌍용스윗닷홈)
# 4        서울특별시 강남구 개포동 1280, 213동 13층1304호 (개포동,래미안블레스티지)
#                               ...
# 2608    서울특별시 중랑구 망우동 0,동 3층 307호   \r\n[도로명주소] 서울특별시 ...
# 2609                    서울특별시 강남구 삼성동  130 삼성이안애빌 3층 304호
# 2610    서울 양천구 신정동  1314, 양천중앙하이츠 102동 9층 906호   \r\n서...
# 2611    서울특별시 노원구 중계동 0,동 8층 805호   \r\n[도로명주소] 서울특별시 ...
# 2612    서울특별시 송파구 마천동  32-1 송파자연채 5층 501호   \r\n서울특별시 ...
# Name: addr, Length: 2613, dtype: object

# %%
data['addr_m']=data['addr'].str.extract('([가-힣\s\d]+)')
data['addr_m']
# Out:
# 0                        서울특별시 송파구 잠실동 22
# 1                     서울특별시 성동구 성수동1가 718
# 2                       서울특별시 광진구 구의동 587
# 3                       서울특별시 동작구 상도동 418
# 4                      서울특별시 강남구 개포동 1280
#                       ...
# 2608                      서울특별시 중랑구 망우동 0
# 2609    서울특별시 강남구 삼성동  130 삼성이안애빌 3층 304호
# 2610                     서울 양천구 신정동  1314
# 2611                      서울특별시 노원구 중계동 0
# 2612                    서울특별시 송파구 마천동  32
# Name: addr_m, Length: 2613, dtype: object

# %%
data['floor'] = data['addr'].str.extract('([0-9]+층)')
data['floor']
# Out:
# 0       22층
# 1       29층
# 2        3층
# 3        9층
# 4       13층
#        ...
# 2608     3층
# 2609     3층
# 2610     9층
# 2611     8층
# 2612     5층
# Name: floor, Length: 2613, dtype: object

# %%
data.head()
# Out:
#     office         num  cat                                              addr  \
# 0   서울동부1계  2020-52099  아파트         서울특별시 송파구 잠실동 22, 265동 22층2201호 (잠실동,리센츠)
# 1   서울동부1계  2020-55340  아파트   서울특별시 성동구 성수동1가 718, 103동 29층2902호 (성수동1가,트리마제)
# 2   서울동부1계  2020-56640  아파트                      서울특별시 광진구 구의동 587-58, 3층303호
# 3  서울중앙10계   2020-3254  아파트       서울특별시 동작구 상도동 418, 101동 9층906호 (상도동,쌍용스윗닷홈)
# 4  서울중앙10계   2020-3339  아파트  서울특별시 강남구 개포동 1280, 213동 13층1304호 (개포동,래미안블레스티지)
#
#           build_area          land_area          price         lowest result  \
# 0   124.22㎡ (37.58평)    58.63㎡ (17.74평)  2,520,000,000  2,520,000,000    NaN
# 1  84.5402㎡ (25.57평)  37.6321㎡ (11.38평)  3,100,000,000  2,480,000,000    NaN
# 2   165.14㎡ (49.95평)     74.3㎡ (22.48평)  1,330,000,000  1,064,000,000    NaN
# 3   59.578㎡ (18.02평)   38.427㎡ (11.62평)    736,000,000    736,000,000    NaN
# 4     29.72㎡ (8.99평)     29.72㎡ (8.99평)  1,585,000,000  1,585,000,000    NaN
#
# ...
